# %% [markdown]
# <h1> My Jupyter Notebook on IBM Watson Studio </h1>

# %% [markdown]
# <b> Folajimi Adeyefa</b>

# %% [markdown]
# Data Analyst

# %% [markdown]
# <i>I am interested in data science because it helps me make decisions that help businesses grow </i>

# %% [markdown]
# ### The value of Sucre

# %%
def sucre (n):
    return (n*(n+1)/2)

sucre (10)
# Out:
# 55.0

# %% [markdown]
# <b><p> unordered list </p></b>
# <p>
# <ul>
# <li> Rice </li>
# <li> Beans </li>
# <li> Stew</li>
# </ul>
# </p>

# %% [markdown]
# **<p> ordered list </p>**
# <p>
# <ol>
# <li> Rice </li>
# <li> Beans </li>
# <li> Stew</li>
# </ol>
# </p>

# %% [markdown]
# <h3> Table for test </h3>
# <table>
# <tr>
# <th>Boy </th>
# <th> Girl </th>
# </tr>
# <tr>
# <td>short </td>
# <td>skirt </td>
# </tr>
# <tr>
# <td>shirt </td>
# <td>blouse </td>
# </tr>
# </table>
